# %%
from PyQt5 import QtCore, QtGui, QtWidgets
import json

class Ambiente:
        def __init__(self, nomeAmbiente, valorLuz, velocidadeM, horarioInicio, horarioFim):            
            self.nomeAmbiente = nomeAmbiente
            self.valorLuz = valorLuz
            self.velocidadeM = velocidadeM
            self.horarioInicio = horarioInicio
            self.horarioFim = horarioFim
          
        def mostrarNome(self):
            print(self.nomeAmbiente)

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(415, 618)
        MainWindow.setCursor(QtGui.QCursor(QtCore.Qt.ArrowCursor))
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.horizontalSlider = QtWidgets.QSlider(self.centralwidget)
        self.horizontalSlider.setGeometry(QtCore.QRect(170, 300, 160, 22))
        self.horizontalSlider.setMaximum(10)
        self.horizontalSlider.setOrientation(QtCore.Qt.Horizontal)
        self.horizontalSlider.setObjectName("horizontalSlider")
        self.label = QtWidgets.QLabel(self.centralwidget)
        self.label.setGeometry(QtCore.QRect(110, 10, 261, 81))
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(self.centralwidget)
        self.label_2.setGeometry(QtCore.QRect(140, 140, 121, 16))
        self.label_2.setObjectName("label_2")
        self.pushButton = QtWidgets.QPushButton(self.centralwidget)
        self.pushButton.setGeometry(QtCore.QRect(160, 560, 75, 23))
        self.pushButton.setObjectName("pushButton")
        self.pushButton.clicked.connect(self.salvarAmbiente)
        self.label_3 = QtWidgets.QLabel(self.centralwidget)
        self.label_3.setGeometry(QtCore.QRect(10, 300, 111, 16))
        self.label_3.setObjectName("label_3")
        self.timeEdit = QtWidgets.QTimeEdit(self.centralwidget)
        self.timeEdit.setGeometry(QtCore.QRect(160, 360, 118, 22))
        self.timeEdit.setObjectName("timeEdit")
        self.label_4 = QtWidgets.QLabel(self.centralwidget)
        self.label_4.setGeometry(QtCore.QRect(10, 340, 131, 16))
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(self.centralwidget)
        self.label_5.setGeometry(QtCore.QRect(50, 370, 47, 13))
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(self.centralwidget)
        self.label_6.setGeometry(QtCore.QRect(50, 400, 47, 13))
        self.label_6.setObjectName("label_6")
        self.timeEdit_2 = QtWidgets.QTimeEdit(self.centralwidget)
        self.timeEdit_2.setGeometry(QtCore.QRect(160, 390, 118, 22))
        self.timeEdit_2.setObjectName("timeEdit_2")
        self.label_7 = QtWidgets.QLabel(self.centralwidget)
        self.label_7.setGeometry(QtCore.QRect(10, 440, 101, 16))
        self.label_7.setObjectName("label_7")
        self.horizontalSlider_2 = QtWidgets.QSlider(self.centralwidget)
        self.horizontalSlider_2.setGeometry(QtCore.QRect(170, 440, 160, 22))
        self.horizontalSlider_2.setMaximum(100)
        self.horizontalSlider_2.setSingleStep(10)
        self.horizontalSlider_2.setOrientation(QtCore.Qt.Horizontal)
        self.horizontalSlider_2.setObjectName("horizontalSlider_2")
        self.plainTextEdit = QtWidgets.QPlainTextEdit(self.centralwidget)
        self.plainTextEdit.setGeometry(QtCore.QRect(53, 160, 301, 31))
        self.plainTextEdit.setPlainText("")
        self.plainTextEdit.setObjectName("plainTextEdit")
        self.lblslider = QtWidgets.QLabel(self.centralwidget)
        self.lblslider.setGeometry(QtCore.QRect(350, 300, 47, 13))
        self.lblslider.setObjectName("lblslider")
        self.label_8 = QtWidgets.QLabel(self.centralwidget)
        self.label_8.setGeometry(QtCore.QRect(350, 440, 47, 13))
        self.label_8.setObjectName("label_8")
        MainWindow.setCentralWidget(self.centralwidget)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        self.horizontalSlider_2.valueChanged['int'].connect(self.label_8.setNum)
        self.horizontalSlider.valueChanged['int'].connect(self.lblslider.setNum)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "adicionarAmbiente"))
        self.label.setText(_translate("MainWindow", "CONFIGURAR NOVO AMBIENTE"))
        self.label_2.setText(_translate("MainWindow", "Nome do Ambiente"))
        self.pushButton.setText(_translate("MainWindow", "Criar"))
        self.label_3.setText(_translate("MainWindow", "Nivel de Luminiosidade"))
        self.label_4.setText(_translate("MainWindow", "Horario de Funcionamento"))
        self.label_5.setText(_translate("MainWindow", "Inicio"))
        self.label_6.setText(_translate("MainWindow", "Fim"))
        self.label_7.setText(_translate("MainWindow", "Velocidade Média"))
        self.lblslider.setText(_translate("MainWindow", "0"))
        self.label_8.setText(_translate("MainWindow", "0"))
        
    def salvarAmbiente(self, MainWindow):
        ambiente = self.plainTextEdit.toPlainText()
        valorLuz = self.horizontalSlider_2.value()
        velocidadeM = self.horizontalSlider.value()
        horarioInicio = self.timeEdit.Time()
        horarioFim = self.timeEdit_2.Time()
        novoAmbiente = Ambiente(ambiente, valorLuz, velocidadeM, horarioInicio, horarioFim)
        
        data = {}
        data['ambiente'] = []
        data['ambiente'].append({
            'nome_ambiente': novoAmbiente.nomeAmbiente,
            'valor_luz': novoAmbiente.valorLuz,
            'velocidade_media': novoAmbiente.velocidadeM,
            'horario_inicial': str(novoAmbiente.horarioInicio),
            'horario_final': str(novoAmbiente.horarioFim)
        })

        with open('data.txt', 'w') as outfile:
            json.dump(data, outfile)
        
        
        

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-4d70d480a690> in salvarAmbiente(self, MainWindow)
#     100         valorLuz = self.horizontalSlider_2.value()
#     101         velocidadeM = self.horizontalSlider.value()
# --> 102         horarioInicio = self.timeEdit.Time()
#     103         horarioFim = self.timeEdit_2.Time()
#     104         novoAmbiente = Ambiente(ambiente, valorLuz, velocidadeM, horarioInicio, horarioFim)
#
# AttributeError: 'QTimeEdit' object has no attribute 'Time'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\Gustavo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
